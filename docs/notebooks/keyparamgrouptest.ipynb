# %% [markdown]
# # Key and Param Group Test

# %%
from cubids import CuBIDS

bod = CuBIDS("/Users/mcieslak/projects/test_bids_data/HBN")
bod._cache_fieldmaps()
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 189.38it/s]
# []

# %%
entity_sets = bod.get_entity_sets()
print(entity_sets)
# Out:
# ['acquisition-64dir_datatype-dwi_suffix-dwi', 'acquisition-HCP_datatype-anat_suffix-T1w', 'acquisition-HCP_datatype-anat_suffix-T2w', 'acquisition-dwi_datatype-fmap_direction-AP_suffix-epi', 'acquisition-dwi_datatype-fmap_direction-PA_suffix-epi', 'acquisition-fMRI_datatype-fmap_direction-AP_suffix-epi', 'acquisition-fMRI_datatype-fmap_direction-PA_suffix-epi', 'datatype-func_run-1_suffix-bold_task-peer', 'datatype-func_run-1_suffix-bold_task-rest', 'datatype-func_run-2_suffix-bold_task-peer', 'datatype-func_run-2_suffix-bold_task-rest', 'datatype-func_run-3_suffix-bold_task-peer', 'datatype-func_suffix-bold_task-movieDM', 'datatype-func_suffix-bold_task-movieTP']

# %%
bod.get_param_groups_from_entity_set('acquisition-64dir_datatype-dwi_suffix-dwi')
# Out:
#    EffectiveEchoSpacing  FlipAngle  RepetitionTime  EchoTime  DwellTime  \
# 0              0.000415         90            3.32    0.1002   0.000003
# 1              0.000415         90            3.32    0.1002   0.000003
# 2              0.000415         90            3.32    0.1002   0.000003
#
#    ParallelReductionFactorInPlane  PartialFourier PhaseEncodingDirection  \
# 0                               2               1                     j-
# 1                               2               1                     j-
# 2                               2               1                     j-
#
#    TotalReadoutTime                                  entity_set  \
# 0          0.042744  acquisition-64dir_datatype-dwi_suffix-dwi
# 1          0.042744  acquisition-64dir_datatype-dwi_suffix-dwi
# 2          0.042744  acquisition-64dir_datatype-dwi_suffix-dwi
#
#                                        FieldmapKey00  \
# 0  acquisition-dwi_datatype-fmap_direction-AP_fma...
# 1  acquisition-dwi_datatype-fmap_direction-AP_fma...
# 2  acquisition-dwi_datatype-fmap_direction-AP_fma...
#
#                                        FieldmapKey01  NSliceTimes  \
# 0  acquisition-dwi_datatype-fmap_direction-PA_fma...            0
# 1  acquisition-dwi_datatype-fmap_direction-PA_fma...            0
# 2  acquisition-dwi_datatype-fmap_direction-PA_fma...            0
#
#                                             FilePath  ParamGroup
# 0  /Users/mcieslak/projects/test_bids_data/HBN/su...           1
# 1  /Users/mcieslak/projects/test_bids_data/HBN/su...           1
# 2  /Users/mcieslak/projects/test_bids_data/HBN/su...           1

# %%
files_df, summary_df = bod.get_param_groups_dataframes()

# %%
files_df
# Out:
#     EffectiveEchoSpacing  FlipAngle  RepetitionTime  EchoTime  DwellTime  \
# 0               0.000415         90           3.320   0.10020   0.000003
# 1               0.000415         90           3.320   0.10020   0.000003
# 2               0.000415         90           3.320   0.10020   0.000003
# 3                    NaN          8           2.500   0.00315   0.000012
# 4                    NaN          8           2.500   0.00315   0.000012
# 5                    NaN          8           2.500   0.00315   0.000012
# 6                    NaN        120           3.200   0.56500   0.000002
# 7               0.000415         90           3.320   0.10020   0.000003
# 8               0.000415         90           3.320   0.10020   0.000003
# 9               0.000415         90           3.320   0.10020   0.000003
# 10              0.000415         90           3.320   0.10020   0.000003
# 11              0.000415         90           3.320   0.10020   0.000003
# 12              0.000415         90           3.320   0.10020   0.000003
# 13              0.000550         90           5.301   0.05120   0.000003
# 14              0.000550         90           5.301   0.05120   0.000003
# 15              0.000550         90           5.301   0.05120   0.000003
# 16              0.000550         90           5.301   0.05120   0.000003
# 17              0.000580         31           0.800   0.03000   0.000003
# 18              0.000580         31           0.800   0.03000   0.000003
# 19              0.000580         31           0.800   0.03000   0.000003
# 20              0.000580         31           0.800   0.03000   0.000003
# 21              0.000580         31           0.800   0.03000   0.000003
# 22              0.000580         31           0.800   0.03000   0.000003
# 23              0.000580         31           0.800   0.03000   0.000003
# 24              0.000580         31           0.800   0.03000   0.000003
# 25              0.000580         31           0.800   0.03000   0.000003
# 26              0.000580         31           0.800   0.03000   0.000003
# 27              0.000580         31           0.800   0.03000   0.000003
# 28              0.000580         31           0.800   0.03000   0.000003
#
#     ParallelReductionFactorInPlane  PartialFourier PhaseEncodingDirection  \
# 0                              2.0               1                     j-
# 1                              2.0               1                     j-
# 2                              2.0               1                     j-
# 3                              2.0               1                    NaN
# 4                              2.0               1                    NaN
# 5                              2.0               1                    NaN
# 6                              2.0               1                    NaN
# 7                              2.0               1                     j-
# 8                              2.0               1                     j-
# 9                              2.0               1                     j-
# 10                             2.0               1                      j
# 11                             2.0               1                      j
# 12                             2.0               1                      j
# 13                             NaN               1                     j-
# 14                             NaN               1                     j-
# 15                             NaN               1                      j
# 16                             NaN               1                      j
# 17                             NaN               1                     j-
# 18                             NaN               1                     j-
# 19                             NaN               1                     j-
# 20                             NaN               1                     j-
# 21                             NaN               1                     j-
# 22                             NaN               1                     j-
# 23                             NaN               1                     j-
# 24                             NaN               1                     j-
# 25                             NaN               1                     j-
# 26                             NaN               1                     j-
# 27                             NaN               1                     j-
# 28                             NaN               1                     j-
#
#     TotalReadoutTime                                          entity_set  ...  \
# 0           0.042744          acquisition-64dir_datatype-dwi_suffix-dwi  ...
# 1           0.042744          acquisition-64dir_datatype-dwi_suffix-dwi  ...
# 2           0.042744          acquisition-64dir_datatype-dwi_suffix-dwi  ...
# 3                NaN           acquisition-HCP_datatype-anat_suffix-T1w  ...
# 4                NaN           acquisition-HCP_datatype-anat_suffix-T1w  ...
# 5                NaN           acquisition-HCP_datatype-anat_suffix-T1w  ...
# 6                NaN           acquisition-HCP_datatype-anat_suffix-T2w  ...
# 7           0.042744  acquisition-dwi_datatype-fmap_direction-AP_suf...  ...
# 8           0.042744  acquisition-dwi_datatype-fmap_direction-AP_suf...  ...
# 9           0.042744  acquisition-dwi_datatype-fmap_direction-AP_suf...  ...
# 10          0.042744  acquisition-dwi_datatype-fmap_direction-PA_suf...  ...
# 11          0.042744  acquisition-dwi_datatype-fmap_direction-PA_suf...  ...
# 12          0.042744  acquisition-dwi_datatype-fmap_direction-PA_suf...  ...
# 13          0.045650  acquisition-fMRI_datatype-fmap_direction-AP_su...  ...
# 14          0.045650  acquisition-fMRI_datatype-fmap_direction-AP_su...  ...
# 15          0.045650  acquisition-fMRI_datatype-fmap_direction-PA_su...  ...
# 16          0.045650  acquisition-fMRI_datatype-fmap_direction-PA_su...  ...
# 17          0.048141          datatype-func_run-1_suffix-bold_task-peer  ...
# 18          0.048141          datatype-func_run-1_suffix-bold_task-peer  ...
# 19          0.048141          datatype-func_run-1_suffix-bold_task-rest  ...
# 20          0.048141          datatype-func_run-1_suffix-bold_task-rest  ...
# 21          0.048141          datatype-func_run-2_suffix-bold_task-peer  ...
# 22          0.048141          datatype-func_run-2_suffix-bold_task-peer  ...
# 23          0.048141          datatype-func_run-2_suffix-bold_task-rest  ...
# 24          0.048141          datatype-func_run-3_suffix-bold_task-peer  ...
# 25          0.048141          datatype-func_run-3_suffix-bold_task-peer  ...
# 26          0.048141             datatype-func_suffix-bold_task-movieDM  ...
# 27          0.048141             datatype-func_suffix-bold_task-movieTP  ...
# 28          0.048141             datatype-func_suffix-bold_task-movieTP  ...
#
#                                              FilePath ParamGroup  \
# 0   /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 1   /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 2   /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 3   /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 4   /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 5   /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 6   /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 7   /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 8   /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 9   /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 10  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 11  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 12  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 13  /Users/mcieslak/projects/test_bids_data/HBN/su...          0
# 14  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 15  /Users/mcieslak/projects/test_bids_data/HBN/su...          0
# 16  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 17  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 18  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 19  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 20  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 21  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 22  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 23  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 24  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 25  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 26  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 27  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
# 28  /Users/mcieslak/projects/test_bids_data/HBN/su...          1
#
#                              IntendedForKey00  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7   acquisition-64dir_datatype-dwi_suffix-dwi
# 8   acquisition-64dir_datatype-dwi_suffix-dwi
# 9   acquisition-64dir_datatype-dwi_suffix-dwi
# 10  acquisition-64dir_datatype-dwi_suffix-dwi
# 11  acquisition-64dir_datatype-dwi_suffix-dwi
# 12  acquisition-64dir_datatype-dwi_suffix-dwi
# 13  datatype-func_run-1_suffix-bold_task-peer
# 14  datatype-func_run-1_suffix-bold_task-peer
# 15  datatype-func_run-1_suffix-bold_task-peer
# 16  datatype-func_run-1_suffix-bold_task-peer
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
#
#                              IntendedForKey01  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13  datatype-func_run-1_suffix-bold_task-rest
# 14  datatype-func_run-1_suffix-bold_task-rest
# 15  datatype-func_run-1_suffix-bold_task-rest
# 16  datatype-func_run-1_suffix-bold_task-rest
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
#
#                              IntendedForKey02  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13  datatype-func_run-2_suffix-bold_task-peer
# 14  datatype-func_run-2_suffix-bold_task-peer
# 15  datatype-func_run-2_suffix-bold_task-peer
# 16  datatype-func_run-2_suffix-bold_task-peer
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
#
#                              IntendedForKey03  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13  datatype-func_run-3_suffix-bold_task-peer
# 14  datatype-func_run-2_suffix-bold_task-rest
# 15  datatype-func_run-3_suffix-bold_task-peer
# 16  datatype-func_run-2_suffix-bold_task-rest
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
#
#                              IntendedForKey04  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13     datatype-func_suffix-bold_task-movieTP
# 14  datatype-func_run-3_suffix-bold_task-peer
# 15     datatype-func_suffix-bold_task-movieTP
# 16  datatype-func_run-3_suffix-bold_task-peer
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
#
#                           IntendedForKey05  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14  datatype-func_suffix-bold_task-movieDM
# 15                                     NaN
# 16  datatype-func_suffix-bold_task-movieDM
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
#
#                           IntendedForKey06 MultibandAccelerationFactor
# 0                                      NaN                         NaN
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
# 3                                      NaN                         NaN
# 4                                      NaN                         NaN
# 5                                      NaN                         NaN
# 6                                      NaN                         NaN
# 7                                      NaN                         NaN
# 8                                      NaN                         NaN
# 9                                      NaN                         NaN
# 10                                     NaN                         NaN
# 11                                     NaN                         NaN
# 12                                     NaN                         NaN
# 13                                     NaN                         NaN
# 14  datatype-func_suffix-bold_task-movieTP                         NaN
# 15                                     NaN                         NaN
# 16  datatype-func_suffix-bold_task-movieTP                         NaN
# 17                                     NaN                         6.0
# 18                                     NaN                         6.0
# 19                                     NaN                         6.0
# 20                                     NaN                         6.0
# 21                                     NaN                         6.0
# 22                                     NaN                         6.0
# 23                                     NaN                         6.0
# 24                                     NaN                         6.0
# 25                                     NaN                         6.0
# 26                                     NaN                         6.0
# 27                                     NaN                         6.0
# 28                                     NaN                         6.0
#
# [29 rows x 23 columns]

# %%
summary_df[["entity_set", "ParamGroup", "Count"]]
# Out:
#                                             entity_set  ParamGroup  Count
# 0           acquisition-64dir_datatype-dwi_suffix-dwi           1      3
# 1            acquisition-HCP_datatype-anat_suffix-T1w           1      3
# 2            acquisition-HCP_datatype-anat_suffix-T2w           1      1
# 3   acquisition-dwi_datatype-fmap_direction-AP_suf...           1      3
# 4   acquisition-dwi_datatype-fmap_direction-PA_suf...           1      3
# 5   acquisition-fMRI_datatype-fmap_direction-AP_su...           0      1
# 6   acquisition-fMRI_datatype-fmap_direction-AP_su...           1      1
# 7   acquisition-fMRI_datatype-fmap_direction-PA_su...           0      1
# 8   acquisition-fMRI_datatype-fmap_direction-PA_su...           1      1
# 9           datatype-func_run-1_suffix-bold_task-peer           1      2
# 10          datatype-func_run-1_suffix-bold_task-rest           1      2
# 11          datatype-func_run-2_suffix-bold_task-peer           1      2
# 12          datatype-func_run-2_suffix-bold_task-rest           1      1
# 13          datatype-func_run-3_suffix-bold_task-peer           1      2
# 14             datatype-func_suffix-bold_task-movieDM           1      1
# 15             datatype-func_suffix-bold_task-movieTP           1      2

# %%
import pandas as pd
param_group_cols = list(set(df.columns.to_list()) - set(["FilePath"]))
uniques = df.drop_duplicates(param_group_cols, ignore_index=True)
print(uniques.shape)
counts = df.groupby(["entity_set", "ParamGroup"]).size().reset_index(name='Count')
print(counts.shape)

params_and_counts = pd.merge(uniques, counts)
print(params_and_counts.shape)

# %%
no_paths[["entity_set", "ParamGroup"]].groupby(["entity_set", "ParamGroup"]).count()

# %%
keyparam_df.groupby(["entity_set", "ParamGroup"]).size().reset_index(name='Count')

# %%
fname = 'sub-NDARAT581NDH/ses-HBNsiteRU/dwi/sub-NDARAT581NDH_ses-HBNsiteRU_acq-64dir_dwi.nii.gz'

# %%
bod.get_entity_sets()

# %%
self = bod

# %%
from cubids.cubids import *
suffix = '(phase1|phasediff|epi|fieldmap)'
fmap_files = self.layout.get(suffix=suffix, regex_search=True,
                             extension=['.nii.gz', '.nii'])

files_to_fmaps = defaultdict(list)

print("\n".join([f.path for f in fmap_files]))

# %%
"""
for fmap_file in tqdm(fmap_files):
    intentions = listify(fmap_file.get_metadata().get("IntendedFor"))
    subject_prefix = "sub-%s/" % fmap_file.entities['subject']
    for intended_for in intentions:
        subject_relative_path = subject_prefix + intended_for
        files_to_fmaps[subject_relative_path].append(fmap_file)
"""
fmap_file = fmap_files[0]
intentions = listify(fmap_file.get_metadata().get("IntendedFor"))
print("intentions:", intentions)
subject_prefix = "sub-%s/" % fmap_file.entities['subject']
print(subject_prefix)

# %%
suffix = '(phase1|phasediff|epi|fieldmap)'
fmap_files = self.layout.get(suffix=suffix, regex_search=True,
                             extension=['.nii.gz', '.nii'])

files_to_fmaps = defaultdict(list)
for fmap_file in tqdm(fmap_files):
    intentions = listify(fmap_file.get_metadata().get("IntendedFor"))
    subject_prefix = "sub-%s" % fmap_file.entities['subject']
    for intended_for in intentions:
        full_path = Path(self.path) / subject_prefix / intended_for
        files_to_fmaps[str(full_path)].append(fmap_file)

# %%
for data_file, fmap_files in bod.fieldmap_lookup.items():
    print(data_file[44:])
    for fmap_file in fmap_files:
        print("   ", fmap_file.path[44:])

# %%
files_to_fmaps.keys()

# %%
from cubids.cubids import *
files = [
 '/Users/mcieslak/projects/test_bids_data/HBN/sub-NDARAT581NDH/ses-HBNsiteRU/dwi/sub-NDARAT581NDH_ses-HBNsiteRU_acq-64dir_dwi.nii.gz',
 '/Users/mcieslak/projects/test_bids_data/HBN/sub-NDARRP384BVX/ses-HBNsiteRU/dwi/sub-NDARRP384BVX_ses-HBNsiteRU_acq-64dir_dwi.nii.gz']

dfs = []
fieldmap_lookup = bod.fieldmap_lookup
entity_set_name = "test"
# path needs to be relative to the root with no leading prefix
for path in files:
    metadata = bod.layout.get_metadata(path)
    wanted_keys = metadata.keys() & IMAGING_PARAMS
    example_data = {key: metadata[key] for key in wanted_keys}
    example_data["entity_set"] = entity_set_name

    # Get the fieldmaps out and add their types
    print(fieldmap_lookup[path])
    fieldmap_types = sorted([fmap.entities['fmap'] for fmap in fieldmap_lookup[path]])
    for fmap_num, fmap_type in enumerate(fieldmap_types):
        example_data['fieldmap_type%02d' % fmap_num] = fmap_type

    # Expand slice timing to multiple columns
    SliceTime = example_data.get('SliceTiming')
    if SliceTime:
        # round each slice time to one place after the decimal
        for i in range(len(SliceTime)):
            SliceTime[i] = round(SliceTime[i], 1)
        example_data.update(
            {"SliceTime%03d" % SliceNum: time for
             SliceNum, time in enumerate(SliceTime)})
        del example_data['SliceTiming']

    dfs.append(example_data)

# %%
example_data
